# %%
# %sql
CREATE OR REPLACE TABLE ecommerce_orders
(
order_id INT,
customer_name STRING,
city STRING,
product STRING,
quantity INT,
price INT,
order_status STRING
)
USING DELTA;

# %%
# %sql
INSERT INTO ecommerce_orders VALUES
(101,'Amit Sharma','Hyderabad','Laptop',1,75000,'Placed'),
(102,'Priya Reddy','Bangalore','Mobile',2,30000,'Placed'),
(103,'Rohit Mehta','Mumbai','Headphones',3,2000,'Shipped'),
(104,'Sneha Iyer','Chennai','Laptop',1,72000,'Placed'),
(105,'Karan Patel','Ahmedabad','Tablet',2,25000,'Cancelled'),
(106,'Ananya Das','Kolkata','Mobile',1,28000,'Placed'),
(107,'Vikram Singh','Delhi','Camera',1,55000,'Placed'),
(108,'Meera Nair','Bangalore','Laptop',1,80000,'Placed');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>8</td><td>8</td></tr></tbody></table></div>

# %%
# %sql
INSERT INTO ecommerce_orders VALUES
(109,'Rahul Varma','Mumbai','Tablet',2,27000,'Placed'),
(110,'Arjun Nair','Mumbai','Mobile',1,27000,'Placed'),
(111,'Sahana Sumanth','Mumbai','Laptop',1,27000,'Placed'),
(112,'Sana Khan','Delhi','Camera',1,50000,'Shipped'),
(113,'Rohit Das','Mumbai','Headphones',5,2000,'Placed'),
(114,'Amit Roy','Hyderabad','Mobile',1,29000,'Placed'),
(115,'Neha Sharma','Hyderabad','Tablet',2,25000,'Placed'),
(116,'Kiran Rao','Hyderabad','Laptop',1,76000,'Placed');
select* from ecommerce_orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
update ecommerce_orders set order_status='Shipped'
where order_id=101;
    
select * from ecommerce_orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
update ecommerce_orders set quantity = quantity + 1 where order_id = 102;
select * from ecommerce_orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
update ecommerce_orders set price=78000
where product='Laptop';
select * from ecommerce_orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
update ecommerce_orders 
set city='Secunderabad' where
customer_name='Amit Sharma';
select* from ecommerce_orders where
customer_name='Amit Sharma'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_name</th><th>city</th><th>product</th><th>quantity</th><th>price</th><th>order_status</th></tr></thead><tbody><tr><td>101</td><td>Amit Sharma</td><td>Secunderabad</td><td>Laptop</td><td>1</td><td>78000</td><td>Shipped</td></tr></tbody></table></div>

# %%
# %sql
update ecommerce_orders 
set order_status='Delivered' where
product='Mobile';
select* from ecommerce_orders where
product='Mobile';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
update ecommerce_orders 
set price=2500 where
product='Headphones';
select* from ecommerce_orders where
product='Headphones';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_name</th><th>city</th><th>product</th><th>quantity</th><th>price</th><th>order_status</th></tr></thead><tbody><tr><td>103</td><td>Rohit Mehta</td><td>Mumbai</td><td>Headphones</td><td>3</td><td>2500</td><td>Shipped</td></tr><tr><td>113</td><td>Rohit Das</td><td>Mumbai</td><td>Headphones</td><td>5</td><td>2500</td><td>Placed</td></tr></tbody></table></div>

# %%
# %sql
update ecommerce_orders 
set price=price+1000 where
product='Tablet';
select* from ecommerce_orders where
product='Tablet';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_name</th><th>city</th><th>product</th><th>quantity</th><th>price</th><th>order_status</th></tr></thead><tbody><tr><td>105</td><td>Karan Patel</td><td>Ahmedabad</td><td>Tablet</td><td>2</td><td>26000</td><td>Cancelled</td></tr><tr><td>109</td><td>Rahul Varma</td><td>Mumbai</td><td>Tablet</td><td>2</td><td>28000</td><td>Placed</td></tr><tr><td>115</td><td>Neha Sharma</td><td>Hyderabad</td><td>Tablet</td><td>2</td><td>26000</td><td>Placed</td></tr></tbody></table></div>

# %%
# %sql
update ecommerce_orders 
set order_status='Processing' where
city='Bangalore';
select* from ecommerce_orders where
city='Bangalore';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_name</th><th>city</th><th>product</th><th>quantity</th><th>price</th><th>order_status</th></tr></thead><tbody><tr><td>102</td><td>Priya Reddy</td><td>Bangalore</td><td>Mobile</td><td>3</td><td>30000</td><td>Processing</td></tr><tr><td>108</td><td>Meera Nair</td><td>Bangalore</td><td>Laptop</td><td>1</td><td>78000</td><td>Processing</td></tr></tbody></table></div>

# %%
# %sql
update ecommerce_orders 
set quantity=2 where
quantity=1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>10</td></tr></tbody></table></div>

# %%
# %sql
update ecommerce_orders 
set city='surat' where
city = 'Ahmedabad';
select* from ecommerce_orders where
city = 'surat';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_name</th><th>city</th><th>product</th><th>quantity</th><th>price</th><th>order_status</th></tr></thead><tbody><tr><td>105</td><td>Karan Patel</td><td>surat</td><td>Tablet</td><td>2</td><td>26000</td><td>Cancelled</td></tr></tbody></table></div>

# %%
# %sql
delete from ecommerce_orders
where order_status='Cancelled';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
delete from ecommerce_orders
where quantity>3;
delete from ecommerce_orders
where product='Camera';
delete from ecommerce_orders
where city='Kolkata';
delete from ecommerce_orders
where price<5000;
delete from ecommerce_orders
where customer_name like 'A%'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>

# %%
# %sql
delete from ecommerce_orders where city = 'Mumbai' and quantity = 1;
delete from ecommerce_orders where price > 80000;
delete from ecommerce_orders where order_id = (select max(order_id) from ecommerce_orders);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %% [markdown]
# # Upsert

# %%
# %sql

CREATE OR REPLACE TEMP VIEW incoming_orders AS
SELECT * FROM VALUES
(102,'Priya Reddy','Bangalore','Mobile',4,30000,'Delivered'),
(104,'Sneha Iyer','Chennai','Laptop',1,72000,'Shipped'),
(109,'Rahul Verma','Mumbai','Tablet',2,26000,'Placed'),
(110,'Divya Menon','Kochi','Mobile',1,27000,'Placed'),
(111,'Farhan Ali','Hyderabad','Laptop',1,79000,'Placed')
AS incoming_orders(order_id,customer_name,city,product,quantity,price,order_status);
-- 1, 2, 3 (basic merge — insert + update)
merge into ecommerce_orders as target
using incoming_orders as source
on target.order_id = source.order_id

when matched then
  update set
    target.customer_name = source.customer_name,
    target.city = source.city,
    target.product = source.product,
    target.quantity = source.quantity,
    target.price = source.price,
    target.order_status = source.order_status

when not matched then
  insert (order_id, customer_name, city, product, quantity, price, order_status)
  values (source.order_id, source.customer_name, source.city, source.product, source.quantity, source.price, source.order_status);

-- 4
select * from ecommerce_orders order by order_id;

-- 5 (check which were inserted — new order_ids like 109,110,111)
select * from ecommerce_orders where order_id in (109, 110, 111);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_name</th><th>city</th><th>product</th><th>quantity</th><th>price</th><th>order_status</th></tr></thead><tbody><tr><td>111</td><td>Farhan Ali</td><td>Hyderabad</td><td>Laptop</td><td>1</td><td>79000</td><td>Placed</td></tr><tr><td>109</td><td>Rahul Verma</td><td>Mumbai</td><td>Tablet</td><td>2</td><td>26000</td><td>Placed</td></tr><tr><td>110</td><td>Divya Menon</td><td>Kochi</td><td>Mobile</td><td>1</td><td>27000</td><td>Placed</td></tr></tbody></table></div>

# %%
# %sql
-- 6 (update only order_status)
merge into ecommerce_orders as target
using incoming_orders as source
on target.order_id = source.order_id

when matched then
  update set target.order_status = source.order_status

when not matched then
  insert (order_id, customer_name, city, product, quantity, price, order_status)
  values (source.order_id, source.customer_name, source.city, source.product, source.quantity, source.price, source.order_status);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
merge into ecommerce_orders as target
using incoming_orders as source
on target.order_id = source.order_id

when matched and source.quantity > target.quantity then
  update set target.quantity = source.quantity

when not matched then
  insert (order_id, customer_name, city, product, quantity, price, order_status)
  values (source.order_id, source.customer_name, source.city, source.product, source.quantity, source.price, source.order_status);

merge into ecommerce_orders as target
using (select * from incoming_orders where order_status != 'Cancelled') as source
on target.order_id = source.order_id

when matched then
  update set *

when not matched then
  insert *;


merge into ecommerce_orders as target
using (select * from incoming_orders where product = 'Laptop') as source
on target.order_id = source.order_id

when matched then
  update set *

when not matched then
  insert *;

merge into ecommerce_orders as target
using incoming_orders as source
on target.order_id = source.order_id

when matched and source.price > target.price then
  update set target.price = source.price

when not matched then
  insert *;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE TEMP VIEW daily_updates AS
SELECT * FROM VALUES
(103,'Rohit Mehta','Mumbai','Headphones',5,2200,'Delivered'),
(106,'Ananya Das','Kolkata','Mobile',2,28000,'Shipped'),
(112,'Sanjay Gupta','Delhi','Tablet',1,24000,'Placed')
AS daily_updates(order_id,customer_name,city,product,quantity,price,order_status);

# %%
# %sql
merge into ecommerce_orders as target
using daily_updates as source
on target.order_id = source.order_id

when matched then
  update set
    target.quantity = source.quantity,
    target.order_status = source.order_status,
    target.price = source.price

when not matched then
  insert (order_id, customer_name, city, product, quantity, price, order_status)
  values (source.order_id, source.customer_name, source.city, source.product, source.quantity, source.price, source.order_status);

-- 4 (count updated rows — order_ids that existed: 103, 106)
select count(*) as updated_rows from ecommerce_orders where order_id in (103, 106);

-- 5 (count inserted rows — new order_id: 112)
select count(*) as inserted_rows from ecommerce_orders where order_id = 112;

-- 6
select * from ecommerce_orders order by price desc;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
